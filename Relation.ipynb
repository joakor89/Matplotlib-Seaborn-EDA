# %% [markdown]
# # Relation
#
# ---
# Seaborn handles relationship graphs between different numerical variables to make from them, visualizations.
#
# Let's see the different graphics that Seaborn has to work with this type of relationship.
#
# ---
# ### Relationship Charts Types in Seaborn
#
# Start by importing the package & data to be used:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ### Scatter

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day', style='time')
plt.show()

# %% [markdown]
# ### Setting up parameters for the Legend

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day', style='time', size='size')
plt.legend(loc='center', bbox_to_anchor=(1.12, 0.5))
plt.show()

# %%
markers = {"Lunch":"D", "Dinner":"s"}
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day', style='time', size='size', markers=markers)
plt.legend(loc='center', bbox_to_anchor=(1.12, 0.5))
plt.show()

# %% [markdown]
# ### Line Plot

# %%
sns.lineplot(data=tips, x='total_bill', y='tip')
plt.show()

# %%
sns.lineplot(data=tips, x='total_bill', y='tip', hue='day', style='time', size='size')
plt.show()

# %% [markdown]
# # Relplot

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='day', style='time', size='size')
plt.show()

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='day', style='time', size='size', col='time')
plt.show()
